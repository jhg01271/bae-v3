# %% [markdown]
# [구글 코랩(Colab)에서 실행하기](https://colab.research.google.com/github/lovedlim/bae-v3/blob/main/part1/ch3/ch3_ex_type1.ipynb)

# %% [markdown]
# - [안내] FutureWarning은 무시해도 됨

# %%
# 흔히 발생하는 FutureWarning
# df['views'].fillna(min, inplace=True)  # 변경 전 (경고 발생 가능)
# df['views'] = df['views'].fillna(min)  # 변경 후 (권장 방식)

# %% [markdown]
# ### Section5.

# %% [markdown]
# ##### 포함 함수 .str.contains('') 기억하기

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'f4'컬럼 데이터에 'FJ'가 포함된 데이터를 찾으시오.
# dir(df['f4'])
# help(df['f4'].isin)
# df[df['f4'].str.]
c = df['f4'].str.contains('FJ')
df = df[c]

# 02. 찾은 데이터 중에서 'f2'컬럼의 평균값을 구하시오.(반올림 후 소수 둘째자리까지 계산)
round(df['f2'].mean(),2)
# Out:
# 0.61

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# f4 컬럼에서 뒤에 2개 값 슬라이싱
df['new'] = df['f4'].str[2:4]

# FJ인 데이터 찾기
cond = df['new'] == 'FJ'
df = df[cond]

# f2 평균 구하기
print(round(df['f2'].mean(), 2))
# Out:
# 0.61

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# FJ인 데이터 찾기
cond = df['f4'].str.contains('FJ')
df = df[cond]

# f2 평균 구하기
print(round(df['f2'].mean(), 2))
# Out:
# 0.61

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'f3'컬럼이 gold이면서 'f2' 컬럼이 2인 데이터를 찾으시오.
c = (df['f3'] == 'gold') & (df['f2']==2)
df = df[c]

# 02. 찾은 데이터에서 'f1'컬럼의 분산을 구하시오(반올림 후 소수 둘째자리까지 계산)
round(df['f1'].var(),2)
# Out:
# 235.43

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 조건에 맞는 데이터
cond1 = df['f3'] == 'gold'
cond2 = df['f2'] == 2
df = df[cond1 & cond2]

# 분산
result = df['f1'].var()

# 출력
print(round(result,2))
# Out:
# 235.43

# %% [markdown]
# ### Section8.

# %% [markdown]
# ##### pd.to_datetime(df['subscribed'])
# - df['y'] = df['subscribed'].dt.year
# - df['m'] = df['subscribed'].dt.month

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'subscribed'컬럼이 2024년 2월인 데이터를 찾으시오.
c = df['subscribed'].str.contains('2024-02')
df = df[c]

# 02. 위에서 찾은 데이터 중 'f3'컬럼이 gold인 데이터의 개수를 구하시오.
c1 = df['f3'] == 'gold'
len(df[c1]) # 5
# Out:
# 5

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'subscribed'컬럼이 2024년 2월인 데이터를 찾으시오.
c = df['subscribed'] = pd.to_datetime(df['subscribed'])
df['y'] = df['subscribed'].dt.year
df['m'] = df['subscribed'].dt.month
df

c1 = df['y'] == 2024
c2 = df['m'] == 2
df = df[c1&c2]

# 02. 위에서 찾은 데이터 중 'f3'컬럼이 gold인 데이터의 개수를 구하시오.
len(df[df['f3'] == 'gold'])
# Out:
# 5

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 자료형 변환
df['subscribed'] = pd.to_datetime(df['subscribed'])
# df['subscribed'] = pd.to_datetime(df['subscribed'], format="%Y-%m-%d") # format 사용

# 파생변수 생성 (년, 월)
df['year'] = df['subscribed'].dt.year
df['month'] = df['subscribed'].dt.month

# 2024년 2월이고, 'f3'이 gold인 데이터
cond1 = df['year'] == 2024
cond2 = df['month'] == 2
cond3 = df['f3'] == 'gold'
df = df[cond1 & cond2 & cond3]

# 데이터 개수
print(len(df))
# Out:
# 5

# %% [markdown]
# ### Section9.

# %% [markdown]
# ##### .value_counts().index[0] 또는 .mode()[0]으로 최빈값 구하기

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'views'컬럼 값이 1000 이하인 데이터(결측치 제외)를 찾으시오.
df = df[df['views'] <= 1000]

# 02. 앞에서 구한 데이터 중 'f4' 컬럼의 최빈값을 구하시오.
# df['f4'].value_counts().index[0] # ISFJ
df['f4'].mode()[0]
# Out:
# 'ISFJ'

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# views수가 1000이하
cond = df['views'] <= 1000
df = df[cond]

# f4컬럼 종류별 개수
df = df['f4'].value_counts()

# f4컬럼 최빈값
print(df.index[0])
# Out:
# ISFJ

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# views수가 1000이하
cond = df['views'] <= 1000
df = df[cond]

# f4컬럼 종류별 개수
print(df['f4'].mode()[0])
# Out:
# ISFJ

# %% [markdown]
# ### Section10.

# %% [markdown]
# ##### df.groupby('city').mean(numeric_only=True) 사용법 유의

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 결측치에 있는 행을 삭제하시오.
df = df.dropna()
# df.info()

# 02. 결측치가 삭제된 데이터를 사용하여 지역별(city)평균을 계산하시오.
# help(df.groupby('city'))
df = df.groupby('city').mean(numeric_only=True)

# 03. 앞에서 계산한 지역별 평균 데이터에서 'f2'컬럼 값이 가장 큰 지역을 구하시오. # 서울
df['f2'].idxmax()
# Out:
# '서울'

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 있는 행은 삭제하고
df.dropna(inplace=True)

# 지역별 평균 계산
df = df.groupby(['city']).mean(numeric_only=True) # 시험환경은 mean() 사용

# 'f2'컬럼이 가장 큰 지역 출력
print(df.sort_values("f2", ascending = False).index[0])
# Out:
# 서울

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 있는 행은 삭제하고
df.dropna(inplace=True)

# 지역별 평균 계산
df = df.groupby('city').mean(numeric_only=True) # 시험환경은 mean() 사용

# 'f2'컬럼이 가장 큰 지역 출력
print(df['f2'].idxmax())
# Out:
# 서울

# %% [markdown]
# ### Section11.

# %% [markdown]
# ##### 버림 .floor(), 올림 .ceil()
# - int(len(df) * 0.7) 앞에서부터 70% 자르기
# - df = df.iloc[:end]

# %%
# 깍두기
import pandas as pd
# import math
df = pd.read_csv("type1_data1.csv")

# 01. 데이터에서 결측치가 있는 데이터(행)을 모두 제거하시오.
# df.info()
df = df.dropna()
# df.info()

# 02. 결측치가 제거된 데이터를 사용하여 앞에서부터 70% 데이터를 구하시오.(단, 데이터 70% 지점의 index가 소수점으로 계산될 경우 소수점 이하는 버림) -> int()하면 버려짐
# dir(df)
c = int(len(df)*0.7)
df = df.iloc[:c]
# df.reset_index()

# 03. 앞에서 구한 70% 데이터 중 'views'컬럼의 3사분위수에서 1사분위수를 뺀 값을 정수로 구하시오.
# help(df.quantile)
int(df['views'].quantile(.75) - df['views'].quantile(.25))
# Out:
# 2771

# %%
import pandas as pd
import math
df = pd.read_csv("type1_data1.csv")

# 01. 데이터에서 결측치가 있는 데이터(행)을 모두 제거하시오.
# df.info()
df = df.dropna()
# df.info()

# 02. 결측치가 제거된 데이터를 사용하여 앞에서부터 70% 데이터를 구하시오.(단, 데이터 70% 지점의 index가 소수점으로 계산될 경우 소수점 이하는 버림)
# dir(df)
df = df.reset_index()
math.floor(70*0.7) # 49
df = df[:49]

# 03. 앞에서 구한 70% 데이터 중 'views'컬럼의 3사분위수에서 1사분위수를 뺀 값을 정수로 구하시오.
# help(df.quantile)
int(df['views'].quantile(.75) - df['views'].quantile(.25))
# Out:
# 2771

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 있는 행 제거
df.dropna(inplace=True)

# 70% 지점
end = int(len(df) * 0.7)

# 70% 데이터 슬라이싱
df = df.iloc[:end]

# 3사분위수, 1사분위수
q3 = df['views'].quantile(.75)
q1 = df['views'].quantile(.25)

# 결과 출력
print(int(q3 - q1))
# Out:
# 2771

# %% [markdown]
# ### Section12.

# %% [markdown]
# - df.isnull().sum()
# - df = df.dropna(subset=['f1'])

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 결측치가 가장 많은 두 컬럼을 찾으시오.
# df.info() # f1, f3
# df.isnull().sum()

# 02. 첫 번째로 결측치가 많은 컬럼에서 결측치가 있는 데이터(행)를 삭제하시오.
df = df.dropna(subset=['f1'])
# help(df.dropna)
df

# 03. 두번째로 결측치가 많은 컬럼을 최빈값으로 대체하시오.
c = df['f3'].value_counts().idxmax() # gold
df['f3'] = df['f3'].fillna(c)

# 04. 'f3'컬럼의 'gold' 값을 가진 데이터의 수를 정수형으로 구하시오.
df['f3'].value_counts() # 63
# Out:
# f3
# gold      63
# silver    15
# vip       11
# Name: count, dtype: int64

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 가장 많은 컬럼, 출력 결과로 확인
#print(df.isnull().sum())

# 결측치가 가장 많은 컬럼 제거
df = df.dropna(subset=['f1'])

# 두번째로 가장 결측치가 많은 컬럼 최빈값 대체
freq = df['f3'].mode()[0]
df['f3'] = df['f3'].fillna(freq)

# f3컬럼이 gold인 데이터의 수
print(sum(df['f3'] == 'gold'))
# Out:
# 63

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 가장 많은 컬럼
col = df.isnull().sum().idxmax()

# 결측치가 가장 많은 컬럼 제거
df = df.dropna(subset=[col])

# 두번째로 가장 결측치가 많은 컬럼 최빈값 대체
freq = df['f3'].mode()[0]
df['f3'] = df['f3'].fillna(freq)

# f3컬럼이 gold인 데이터의 수
print(len(df[df['f3'] == 'gold']))
# Out:
# 63

# %% [markdown]
# ### Section14.

# %% [markdown]
# - mapping = {'silver':1,'gold':2,'vip':3}
# - df['f3'] = df['f3'].replace(mapping)
# - map보다 replace추천: map쓰려면 0에 대해서도 규칙 써줘야함 0:0

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 중복 데이터를 제거하시오.
# dir(pd)
# dir(df)
df = df.drop_duplicates()

# 02. 'f3' 컬럼의 결측치는 0, 'silver'는 1, 'gold'는 2, 'vip'는 3으로 변환하시오. (map보다 replace추천: map쓰려면 0에 대해서도 규칙 써줘야함 0:0)
mapping = {'silver':1,'gold':2,'vip':3}
df['f3'] = df['f3'].replace(mapping)
df['f3'].value_counts()

# 03. 변환된 'f3'컬럼의 총합을 정수형으로 구하시오. 
int(df['f3'].sum())
# Out:
# C:\Users\iljoo\AppData\Local\Temp\ipykernel_13500\3733760824.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['f3'] = df['f3'].replace(mapping)
# 167

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 중복 데이터를 제거하시오.
df = df.drop_duplicates()
df

# 02. 'f3' 컬럼의 결측치는 0, 'silver'는 1, 'gold'는 2, 'vip'는 3으로 변환하시오. (map보다 replace추천: map쓰려면 0에 대해서도 규칙 써줘야함 0:0)
df['f3'] = df['f3'].fillna(0)
mapping = {'silver':1,'gold':2,'vip':3}
# help(df['f3'].map)
df['f3'] = df['f3'].replace(mapping)
df['f3'].value_counts()

# 03. 변환된 'f3'컬럼의 총합을 정수형으로 구하시오. 
int(df['f3'].sum())
# Out:
# C:\Users\iljoo\AppData\Local\Temp\ipykernel_41728\1587783712.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['f3'] = df['f3'].replace(mapping)
# 167

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 중복 데이터를 제거하시오.
df = df.drop_duplicates()
df

# 02. 'f3' 컬럼의 결측치는 0, 'silver'는 1, 'gold'는 2, 'vip'는 3으로 변환하시오. (데이터 오염 높아 비추천)
df['f3'] = df['f3'].fillna(0)
c1 = df['f3'] == 'silver'
c2 = df['f3'] == 'gold'
c3 = df['f3'] == 'vip'
df[c1] = 1
df[c2] = 2
df[c3] = 3
df['f3'].value_counts()

# 03. 변환된 'f3'컬럼의 총합을 정수형으로 구하시오. 
int(df['f3'].sum())
# Out:
# 167

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 중복데이터 제거
df = df.drop_duplicates()

# 값 대체
import numpy as np
dict_list = {np.nan:0, 'silver':1, 'gold':2, 'vip':3}
df['f3'] = df['f3'].map(dict_list)

# f3컬럼의 총합 (정수형으로 출력)
print(int(df['f3'].sum()))
# Out:
# 167

# %%
# 방법2
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 중복데이터 제거
df.drop_duplicates(inplace=True)

# 계산
r1 = sum(df['f3'] == 'silver') * 1
r2 = sum(df['f3'] == 'gold') * 2
r3 = sum(df['f3'] == 'vip') * 3
print(r1 + r2 + r3)
# Out:
# 167

# %% [markdown]
# ### Section15.

# %% [markdown]
# - df.sum(axis=1)을 써주면 좌에서 우로(가로 방향) 각 행의 합을 구해줌

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 주어진 데이터에서 문자 자료형 컬럼을 삭제하시오.
# help(df.drop)
# dir(df)
# help(df.select_dtypes)
df = df.select_dtypes(exclude=['object'])
# print(df.info())
# 02. 숫자 자료형 컬럼의 결측치를 0으로 대체하시오.
df = df.fillna(0)
# df.info()

# 03. 각 행의 합이 3000보다 큰 값의 개수를 정수로 구하시오. (각 행의 합: 'age'+'f1'+'f2'+'f5'+'views')
df['sum'] = df.sum(axis=1)
int(len(df[df['sum'] > 3000]))
# Out:
# 88

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 자료형이 object 컬럼 선택
cols = df.select_dtypes(exclude='object').columns
df = df[cols]

# 결측치 0으로 대체
df = df.fillna(0)

# 행과 열 변경
df = df.T

# 행별 합이 3000이상인 데이터 수
print(sum(df.sum() > 3000))
# Out:
# 88

# %% [markdown]
# ### Section16.

# %% [markdown]
# - q1 = df['views'].quantile(.25)
# -  q3 = df['views'].quantile(.75)
# -  iqr = q3 - q1
# -
# - df = df[c3 | c4]

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'views'컬럼의 1사분위수, 3사분위수 그리고 IQR을 계산하시오.
dir(df)
q1 = df['views'].quantile(.25)
q3 = df['views'].quantile(.75)
iqr = q3 - q1
iqr

# 02. 이상치 조건에 맞는 데이터를 찾으시오.(이상치는 1사분위수 - (IQR * 1.5)보다 작은 값과 3사분위수 + (IQR * 1.5) 보다 큰 값)
c3 = df['views'] < q1 - iqr * 1.5 
c4 = df['views'] > q3 + iqr * 1.5
df = df[c3 | c4]

# 03. 이상치 데이터의 'views'컬럼 합을 정수로 구하시오.
int(df['views'].sum())
# Out:
# 77699

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 3사분위 1사분위
q3 = df['views'].quantile(.75)
q1 = df['views'].quantile(.25)

# IQR 계산
IQR = q3 - q1

# 이상치 기준 찾기
line1 = q1 - 1.5 * IQR
line2 = q3 + 1.5 * IQR

# 이상치 조건에 만족하는 데이터 찾기
cond1 = df['views'] < line1
cond2 = df['views'] > line2
df = df[cond1 | cond2]

# views 컬럼 합
print(int(df['views'].sum()))
# Out:
# 77699

# %% [markdown]
# ### Section17.

# %% [markdown]
# - 소수점이 존재하는 값 제거: df = df[df['age'] == df['age'].astype(int)]
# - cond = df['age'] == round(df['age'],0)

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'views'컬럼의 표준편차를 구하시오.
c1 = df['views'].std()

# 02. 'age'컬럼의 이상치(소수점 나이, 음수 나이, 0살)를 제거하고, 'views'컬럼의 표준편차를 구하시오.
df = df[df['age'] > 0]
df['age'].value_counts()
# help(df['age'].astype)
df = df[df['age'] == df['age'].astype(int)]

# 03. 이상치 제거 전후의 'views'컬럼의 표준편차를 더하여, 반올림 후 소수 둘째자리까지 구하시오. 
c2 = df['views'].std()
round(c1+c2,2)
# Out:
# 8297.31

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 표준편차
r1 = df['views'].std()

# 음수이거나 0 테이터 제외
cond = df['age'] <= 0
df = df[~cond]

# 소수점이 없는 값만 선택
cond = df['age'] == round(df['age'],0)
df = df[cond]

# 표준편차
r2 = df['views'].std()

print(round(r1 + r2, 2))
# Out:
# 8297.31

# %% [markdown]
# ### Section18.

# %% [markdown]
# ##### 02. index '2003'데이터(행)에서 평균보다 작은 값의 개수를 구하시오.
# - mean_2003 = df.loc[2003].mean() # 97.215
# - len(df.loc[2003][df.loc[2003] < mean_2003])

# %%
import pandas as pd
df = pd.read_csv("type1_data2.csv", index_col="year")

# # 01. index '2001'데이터(행)에서 평균보다 큰 값의 개수를 구하시오.
# df1 = df.copy()
# df1['mean'] = df1.mean(axis=1) # 	104.235
# mean_2001 = df1.iloc[1,-1]
# c1 = len(df.T[df.T[2001] > mean_2001])

# # 02. index '2003'데이터(행)에서 평균보다 작은 값의 개수를 구하시오.
# mean_2003 = df.loc[2003].mean() # 97.215
# len(df.loc[2003][df.loc[2003] < mean_2003])

# 03. 두 개수를 더하시오.
# c1 + c2

df.loc[2003]
# Out:
# 0       78
# 1       45
# 2       26
# 3       50
# 4      177
#       ...
# 195     83
# 196      5
# 197     75
# 198    196
# 199    119
# Name: 2003, Length: 200, dtype: int64

# %%
import pandas as pd
# df = pd.read_csv("type1_data2.csv", index_col="year")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data2.csv", index_col="year")

# 2001, 평균보다 큰값 합계
m1 = df.loc[2001].mean()
cond1 = df.loc[2001] > m1
r1 = sum(cond1)

# 2003평균보다 작은값 합계
m2 = df.loc[2003].mean()
cond2 = df.loc[2003] < m2
r2 = sum(cond2)

print(r1+r2)
# Out:
# 202

# %%
import pandas as pd
# df = pd.read_csv("type1_data2.csv", index_col="year")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data2.csv", index_col="year")
df = df.T # 행과 열 변경

# 평균보다 큰값 합계
m1 = df[2001].mean()
cond1 = df[2001] > m1
r1 = sum(cond1)

# 평균보다 작은값 합계
m2 = df[2003].mean()
cond2 = df[2003] < m2
r2 = sum(cond2)

print(r1+r2)
# Out:
# 202

# %% [markdown]
# ### Section19.

# %% [markdown]
# - df.bfill(): 결측치 바로 뒤에 있는값으로 대체
# - df = df.groupby(['city','f2']).sum(numeric_only=True) # .reset_index()를 붙이면 연산 처리하기 좋음

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 결측치를 바로 뒤에 있는 값으로 대체하시오.(바로 뒤의 값도 결측치일 경우, 뒤에 있는 데이터 중 가장 가까운 값으로 대체)
df = df.bfill()
# dir(df)
df

# 02. 'city'와 'f2'컬럼을 기준으로 그룹합을 계산하시오.
df = df.groupby(['city','f2']).sum(numeric_only=True) # .reset_index()를 붙이면 연산 처리하기 좋음

# 03. 'views'값이 세 번째로 큰 city이름을 구하시오.
# dir(df['views'])
df['views'].nlargest(3) # 경기
# Out:
# city  f2
# 경기    0     154066.0
# 대구    0     100421.0
# 경기    1      91442.0
# Name: views, dtype: float64

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치 채우기
df = df.bfill()

# city와 f2기준 그룹합 계산
df = df.groupby(['city','f2']).sum(numeric_only=True).reset_index()

# 내림차순 정렬
df = df.sort_values('views', ascending=False)

# 3번째로 큰 값 출력
print(df.iloc[2,0])
# Out:
# 경기

# %% [markdown]
# ### Section20.

# %% [markdown]
# - to_datetime앞에 pd이다. pd.to_datetime(df['subscribed'])

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 연도 구분 없이 월별로 숫자형 컬럼의 합을 구하시오.
df['subscribed'] = pd.to_datetime(df['subscribed'])

# dir(df['subscribed'])
df['month'] = df['subscribed'].dt.month
df = df.groupby('month').sum(numeric_only=True)
df

# 02. 합계 중 'views'가 가장 작은 값을 가진 월을 정수로 구하시오. 
int(df['views'].idxmin())
# Out:
# 11

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 자료형 변환
df['subscribed'] = pd.to_datetime(df['subscribed'])

# 파생변수 생성
df['month'] = df['subscribed'].dt.month

# 월별로 데이터 합 집계
df = df.groupby('month').sum(numeric_only=True)

# 오름차순 정렬 및 가장 작은값 출력
print(df.sort_values('views').index[0])
# Out:
# 11

# %% [markdown]
# ### Section21.

# %% [markdown]
# - 날짜 계산 전 pd.to_datetime 필수!
# - .dt.total_seconds()/60하면 분단위로 계산 가능

# %%
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 예상 도착 시간보다 늦게 도착한 건수를 구하시오.
df['예상도착시간'] = pd.to_datetime(df['예상도착시간'])
df['실제도착시간'] = pd.to_datetime(df['실제도착시간'])
df = df[df['예상도착시간'] < df['실제도착시간']] # 데이터가 이쁘게 안들어가 있다면 위험함
len(df)

# 02. 이 중 거리가 7km 이상인 데이터의 수를 정수로 구하시오. 
len(df[df['거리'] >= 7])
# Out:
# 311

# %%
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 예상 도착 시간보다 늦게 도착한 건수를 구하시오.
df = df[df['예상도착시간'] < df['실제도착시간']] # 데이터가 이쁘게 안들어가 있다면 위험함
len(df)

# 02. 이 중 거리가 7km 이상인 데이터의 수를 정수로 구하시오. 
len(df[df['거리'] >= 7])
# Out:
# 311

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# datetime으로 자료형 변경
df['실제도착시간'] = pd.to_datetime(df['실제도착시간'])
df['예상도착시간'] = pd.to_datetime(df['예상도착시간'])

# 지연시간 계산(분)
df['지연시간'] = (df['실제도착시간'] - df['예상도착시간']).dt.total_seconds()/60

# 조건1 - 예상 도착시간보다 늦게 도착한 건
cond1 = df['지연시간'] > 0

# 조건2 - 거리가 7 이상인 건
cond2 = df['거리'] >= 7

# 조건에 맞는 데이터(행) 수 출력
print(len(df[cond1 & cond2]))
# Out:
# 311

# %% [markdown]
# ### Section23.

# %% [markdown]
#  - c = df['지연시간'] > 0
#  - df['지연여부'] = c
#  - df = df.groupby('결제종류').mean(numeric_only=True)
# - 지연여부가 1 또는 0으로 산출되므로 비율을 자동으로 나타내줌

# %%
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 각 결제 종류별로 실제 도착 시간이 예상 도착 시간보다 늦은 주문의 비율을 계산하시오.
df['실제도착시간'] = pd.to_datetime(df['실제도착시간'])
df['예상도착시간'] = pd.to_datetime(df['예상도착시간'])
df['지각여부'] = (df['실제도착시간'] - df['예상도착시간']).dt.total_seconds() > 0

df = df.groupby('결제종류').mean(numeric_only=True)

# 02. 비율 중 가장 큰 값을 반올림하여 소수 둘째 자리까지 구하시오. 
round(df['지각여부'].max(),2)
# Out:
# 0.56

# %%
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 각 결제 종류별로 실제 도착 시간이 예상 도착 시간보다 늦은 주문의 비율을 계산하시오.
df['실제도착시간'] = pd.to_datetime(df['실제도착시간'])
df['예상도착시간'] = pd.to_datetime(df['예상도착시간'])
df['지연시간'] = (df['실제도착시간'] - df['예상도착시간']).dt.total_seconds()
df
c = df['지연시간'] > 0
df['지연여부'] = c
df = df.groupby('결제종류').mean(numeric_only=True)
df

# 02. 비율 중 가장 큰 값을 반올림하여 소수 둘째 자리까지 구하시오. 
round(df['지연여부'].max(),2) # 0.56
# Out:
# 0.56

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# datetime 자료형으로 변경
df['실제도착시간'] = pd.to_datetime(df['실제도착시간'])
df['예상도착시간'] = pd.to_datetime(df['예상도착시간'])

# 지연시간 계산(분)
df['지연시간'] = (df['실제도착시간'] - df['예상도착시간']).dt.total_seconds() / 60  # 분 단위로 계산

# 실제 도착시간이 예상 도착시간보다 늦은 경우를 체크하는 컬럼 생성
df['지연여부'] = df['지연시간'] > 0

# 결제 종류별 지연된 주문의 비율 계산
result = df.groupby('결제종류')['지연여부'].mean()

# 가장 비율이 높은 값
print(round(result.max(), 2))
result
# Out:
# 0.56
# 결제종류
# 앱결제    0.556634
# 카드     0.489971
# 현금     0.488304
# Name: 지연여부, dtype: float64

# %% [markdown]
# ### Section24.

# %% [markdown]
# - df[df['user'].isin(c)]: 리스트 안에 포함되는 값들 필터링

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 사용자별 주문 거리의 합계가 50km 이상인 사람들의 결제 방식을 구하시오. 
df_user = df.groupby('user').sum()
df_user = df_user[df_user['거리'] >= 50]
print(df_user.index)

df = df[df['user'].isin(df_user.index)]

# 02. 이 결제 방식 중 가장 빈도가 높은 수를 구하시오. 
df = df['결제종류'].value_counts()
df
df.iloc[0]
# Out:
# Index(['user_116', 'user_133', 'user_157', 'user_176', 'user_19', 'user_20',
#        'user_204', 'user_211', 'user_251', 'user_255', 'user_311', 'user_318',
#        'user_338', 'user_342', 'user_360', 'user_366', 'user_368', 'user_369',
#        'user_383', 'user_385', 'user_397', 'user_398', 'user_430', 'user_434',
#        'user_441', 'user_497', 'user_80', 'user_85'],
#       dtype='object', name='user')
# 48

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 사용자별 주문 거리의 합계가 50km 이상인 사람들의 결제 방식을 구하시오. 
df_user = df.groupby('user').sum()
df_user = df_user[df_user['거리'] >= 50]
c = df_user.index
df = df[df['user'].isin(c)]
df = df['결제종류'].value_counts()

# # 02. 이 결제 방식 중 가장 빈도가 높은 수를 구하시오. 
# df.iloc[0]
df
df_user.index
# Out:
# Index(['user_116', 'user_133', 'user_157', 'user_176', 'user_19', 'user_20',
#        'user_204', 'user_211', 'user_251', 'user_255', 'user_311', 'user_318',
#        'user_338', 'user_342', 'user_360', 'user_366', 'user_368', 'user_369',
#        'user_383', 'user_385', 'user_397', 'user_398', 'user_430', 'user_434',
#        'user_441', 'user_497', 'user_80', 'user_85'],
#       dtype='object', name='user')

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")
df.head()

# 사용자별로 주문 거리의 합계와 평균 계산
df_distance = df.groupby('user')['거리'].sum()

# 주문 거리의 합계가 50km 이상인 사용자만 필터링
cond = df_distance >= 50
df_distance = df_distance[cond]

# 주문 거리의 합계가 50km 이상인 사용자들의 데이터 필터링
filtered_data = df[df['user'].isin(df_distance.index)]
filtered_data

# 해당 사용자들의 선호 결제 방식 중 큰 값
payment_method = filtered_data['결제종류'].value_counts()
print(payment_method.iloc[0])
# Out:
# 48

# %% [markdown]
# ### Section25.

# %% [markdown]
# - 각 사용자별 첫주문시간 필터링: first = df.groupby('user')['주문시간'].min()
# - 안덱스차이때문에 원본 데이터프레임에 억지로 값을 집어넣을 필요 없이, 유저별로 요약된 결과 내에서 바로 계산하는게 좋음
# - 날짜 간격에서는 df.day가 아닌 dt.days사용

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 각 사용자별로 첫 주문과 마지막 주문 사이의 시간 간격을 일 단위로 계산하시오. 
df['주문시간'] = pd.to_datetime(df['주문시간'])
user_min = df.groupby('user')['주문시간'].min()
user_max = df.groupby('user')['주문시간'].max()

# 02. 시간차가 0일인 사용자를 제외하고, 나머지 사용자들의 평균 시간 간격(일 단위)을 계산하시오.
meter = (user_max - user_min).dt.days
meter = meter[meter > 0]
m_avg = meter.mean()

# 03. 평균 시간 간격보다 긴 시간 간격을 가진 사용자의 수를 정수로 구하시오. 
len(meter[meter > m_avg])
# Out:
# 146

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 각 사용자별로 첫 주문과 마지막 주문 사이의 시간 간격을 일 단위로 계산하시오. 
df['주문시간'] = pd.to_datetime(df['주문시간'])
# dir(df.groupby('user'))
first = df.groupby('user')['주문시간'].min()
last = df.groupby('user')['주문시간'].max()
c = (last-first).dt.days
c

# 02. 시간차가 0일인 사용자를 제외하고, 나머지 사용자들의 평균 시간 간격(일 단위)을 계산하시오.
day = c[c > 0].mean()
day

# 03. 평균 시간 간격보다 긴 시간 간격을 가진 사용자의 수를 정수로 구하시오. 
int(len(c[c>day]))
# Out:
# 146

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# 각 사용자별로 첫 주문과 마지막 주문 사이의 시간 간격(일 단위)을 계산
df['주문시간'] = pd.to_datetime(df['주문시간'])
min_order_time = df.groupby('user')['주문시간'].min()
max_order_time = df.groupby('user')['주문시간'].max()
time_interval = (max_order_time - min_order_time).dt.days

# 1회 이하 주문 제외
cond1 = time_interval>0
m = time_interval[cond1].mean()

# 평균보다 기간이 긴 유저 수
cond2 = time_interval > m
print(len(time_interval[cond2]))
# Out:
# 146

# %% [markdown]
# ### Section28.

# %% [markdown]
# - df.groupby('user')['거리'].count(): 결측치를 빼고 반환합니다
# - df.groupby('user')['거리'].size(): 결측치 상관없이 총 줄 수를 반환합니다

# %%
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 연도와 월을 기준으로 주문 수를 집계하시오.
# df['주문시간'] = pd.to_datetime(df['주문시간'])
df['연월'] = df['주문시간'].str[:7]
df = df.groupby('연월').count()
df

# 02. 가장 많은 주문이 있었던 연도와 월을 예시와 같은 형식으로 숫자로만 구하시오.(예: 2024년 2월인 경우 '202402', 2024년 10월인 경우 '202410')
df.idxmax()[0].replace('-','')
# Out:
# C:\Users\iljoo\AppData\Local\Temp\ipykernel_67724\1737276749.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.idxmax()[0].replace('-','')
# '202209'

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# 주문 연월 추출 (연도-월)
df['주문시간'] = pd.to_datetime(df['주문시간'])
df['주문월'] = df['주문시간'].dt.to_period('M')

# 주문월을 기준으로 빈도 수(주문 횟수) 계산
count_month = df.groupby('주문월').size()

# 주문 횟수가 가장 많은 월의 인덱스 추출
year_month = count_month.idxmax()

# 문자열로 변경 및 하이픈(-) 제거
year_month = str(year_month)
result = year_month.replace("-","")
print(result)
# Out:
# 202209

# %% [markdown]
# ### Section29.

# %% [markdown]
# - df['배달료'] = pd.cut(df['거리'], [0, 5, 10, 15, 20], labels=[2000, 4000, 6000, 8000])
# - df['배달료'] = df['배달료'].astype(int)
#
# - df['배달료'] = df['거리'].apply(cal)

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 배달료 계산 기준표에 따라 각 주문에 대한 배달료를 계산하시오. 
df['배달료'] = pd.cut(df['거리'],[0,5,10,15,20],labels=[2000,4000,6000,8000])

# help(pd.cut)
# 02. 월별로 배달료의 총합을 집계하시오. 
df['배달료'] = df['배달료'].astype(int)
df['주문시간'] = pd.to_datetime(df['주문시간'])
df['월'] = df['주문시간'].dt.month
df = df.groupby('월')['배달료'].sum()
df
# 03. 배달료가 가장 많이 발생하는 월을 찾고, 그 월의 총 배달료를 정수로 구하시오. 
df.idxmax()
df.max()
# Out:
# 448000

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 배달료 계산 기준표에 따라 각 주문에 대한 배달료를 계산하시오. 
def cal(x):
    if x < 5:
        return 2000
    elif x < 10:
        return 4000
    elif x < 15:
        return 6000
    elif x < 20:
        return 8000

df['배달료'] = df['거리'].apply(cal)
df

# 02. 월별로 배달료의 총합을 집계하시오. 
df['주문시간'] = pd.to_datetime(df['주문시간'])
df['월'] = df['주문시간'].dt.month
df = df.groupby('월')['배달료'].sum()
df

# 03. 배달료가 가장 많이 발생하는 월을 찾고, 그 월의 총 배달료를 정수로 구하시오. 
df.idxmax() # 6월
df.max() # 448000
# Out:
# 448000

# %%
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 배달료 계산 기준표에 따라 각 주문에 대한 배달료를 계산하시오. 
# help(pd.cut)
df['배달료'] = pd.cut(df['거리'], [0, 5, 10, 15, 20], labels=[2000, 4000, 6000, 8000])
df

# 02. 월별로 배달료의 총합을 집계하시오. 
df['배달료'] = df['배달료'].astype(int)
df['주문시간'] = pd.to_datetime(df['주문시간'])
df['월'] = df['주문시간'].dt.month
df = df.groupby('월')['배달료'].sum()
df

# 03. 배달료가 가장 많이 발생하는 월을 찾고, 그 월의 총 배달료를 정수로 구하시오. 
df.idxmax() # 6월
df.max() # 448000
# Out:
# 448000

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# 배달료 계산 함수 정의
def delivery_fee(distance):
    if distance < 5:
        return 2000
    elif distance < 10:
        return 4000
    elif distance < 15:
        return 6000
    elif distance < 20:
        return 8000

# 각 주문에 대한 배달료 계산
df['배달료'] = df['거리'].apply(delivery_fee)

# 월별로 배달료 집계
df['주문시간'] = pd.to_datetime(df['주문시간'])
period_M = df['주문시간'].dt.to_period("M")
monthly = df.groupby(period_M)['배달료'].sum()

# 가장 많은 배달료가 발생한 월과 그 월의 총 배달료 찾기
max_fee_month = monthly.idxmax()
max_fee_value = monthly[max_fee_month]
print(max_fee_value)
# Out:
# 448000

# %% [markdown]
# ### Section30.

# %% [markdown]
# - dt.dayofweek와 dt.weekday 같은 기능 0:월 부터 시작

# %%
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 주말 주문 건수와 평일 주문 건수를 구하시오. 
df['주문시간'] = pd.to_datetime(df['주문시간'])
df['요일'] = df['주문시간'].dt.weekday
c1 = df['요일'] >= 5
c2 = df['요일'] < 5 
len(df[c1]), len(df[c2])
# dir(df['주문시간'].dt)

# 02. 주말 주문 건수와 평일 주문 건수의 차이를 절대값으로 구하고 정수형으로 구하시오. 
int(abs(len(df[c2]) - len(df[c1])))
# Out:
# 412

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")
df['주문시간'] = pd.to_datetime(df['주문시간'])

# 주말/평일 구분 0:월, 1:화 ~ 5:토, 6:일
df['dayofweek'] = df['주문시간'].dt.dayofweek
df['주말'] = df['dayofweek'] >= 5

# 주말 개수, 평일 개수 계산
weekend = sum(df['주말'])
weekday = sum(~df['주말'])

# 차이 절대값 출력
print(abs(weekend - weekday))
# Out:
# 412

# %% [markdown]
# ### Section32.

# %% [markdown]
# - df['total_score'] = df[['수학', '영어', '국어']].sum(axis=1)

# %%
import pandas as pd
df = pd.read_csv("school_data.csv")

# 01. 수학, 영어, 국어 점수의 합을 구하시오. 
df['점수합'] = df.sum(axis=1, numeric_only=True)
df
# 02. 합이 가장 큰 상위 10명을 찾으시오. 
c = df['점수합'].nlargest(10)

# 03. 찾은 10명의 수학 평균 점수를 구하시오.(반올림 후 정수 출력)
df = df[df['점수합'].isin(c)]
int(round(df['수학'].mean()))
# Out:
# 82

# %%
import pandas as pd
# df = pd.read_csv("school_data.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data.csv")

# 수학, 영어, 국어 점수 합계
df['total_score'] = df[['수학', '영어', '국어']].sum(axis=1)

# 합계 점수를 기준으로 상위 10명 선택
top10 = df.nlargest(10, 'total_score')

# 선택된 10명의 수학 평균 점수 계산
result = top10['수학'].mean()
print(round(result))
# Out:
# 82

# %% [markdown]
# ### Section33.

# %% [markdown]
# - 데이터를 밑으로 길게 이어 붙이기: melt_df = df.melt(id_vars=['이름'],value_vars=['수학','영어','국어'])

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("school_data.csv")

# 01. 과목에 상관없이 점수가 가장 작은 점수 25개를 찾으시오. 
# help(df.melt)
df = df.melt(id_vars='이름', value_vars=['국어','영어','수학'])
df
df = df.nsmallest(25,'value')
# 02. 찾은 점수 25개의 합을 정수로 구하시오. 
df['value'].sum()
# Out:
# 420

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("school_data.csv")
df.head()
# Out:
#     이름  수학  영어  국어 수학교사 영어교사 국어교사
# 0  강아지  66  61  26  김선생  장선생  최선생
# 1  고양이  92  48  80  김선생  장선생  이선생
# 2   토끼  98   7   6  김선생  장선생  최선생
# 3   사자  17  99  14  김선생  유선생  최선생
# 4  호랑이  83  92  75  박선생  장선생  이선생

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("school_data.csv")

# 01. 과목에 상관없이 점수가 가장 작은 점수 25개를 찾으시오. 
melt_df = df.melt(id_vars=['이름'],value_vars=['수학','영어','국어'])
df = melt_df.nsmallest(25,'value')
# melt_df
# help(melt_df.nsmallest)

# 02. 찾은 점수 25개의 합을 정수로 구하시오. 
int(df['value'].sum())
# Out:
# 420

# %%
import pandas as pd
# df = pd.read_csv("school_data.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data.csv")

# 이름을 유지하면서 수학, 영어, 국어 형태 변경
melted_df = df.melt(id_vars=['이름'], value_vars=['수학', '영어', '국어'])

# 가장 작은 값 25개의 합
result = melted_df['value'].nsmallest(25).sum()
print(result)
# Out:
# 420

# %% [markdown]
# ### Section34.

# %% [markdown]
# - 밑에 붙이는게 아닌 옆으로 병합: combined = pd.concat([df, df_science], axis=1)

# %%
import pandas as pd
df = pd.read_csv("school_data.csv")
df_science = pd.read_csv("school_data_science.csv")

# 01. 주어진 두 csv파일을 학생 순서를 기준으로 병합하시오.(단, 두 파일의 학생 순서는 동일하다)
df = pd.concat([df, df_science], axis=1)

# 02. 학생별로 수학, 영어, 국어, 과학 점수의 평균을 구하시오. 
df['평균'] = df[['수학','영어','국어','과학']].mean(axis=1)
df
# 03. 평균 점수가 60점 이상인 인원 수를 계산하시오. 
len(df[df['평균'] >= 60])
# Out:
# 9

# %%
import pandas as pd
# df = pd.read_csv("school_data.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data.csv")
# df_science = pd.read_csv("school_data_science.csv")
df_science = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data_science.csv")

# 두 데이터프레임 합치기(axis=1)
df = pd.concat([df, df_science], axis=1)

# 수평(열)으로 평균 계산
df['수영국과 평균'] = df[['수학', '영어', '국어', '과학']].mean(axis=1)

# 수학, 영어, 국어, 과학 평균이 60점 이상
result = sum(df['수영국과 평균'] >= 60)
print(result)
# Out:
# 9

# %% [markdown]
# ### Section35.

# %% [markdown]
# - df = df.merge(df_social, on='이름')

# %%
import pandas as pd
df = pd.read_csv("school_data.csv")
df_social = pd.read_csv("school_data_social.csv")

# 01. 두 csv파일을 '이름'을 기준으로 합치시오.
df = df.merge(df_social, on='이름')
df

# 02. 영어교사가 장선생이면서 사회교사가 오선생인 학생들을 필터링하시오. 
c1 = df['영어교사'] =='장선생' 
c2 = df['사회교사'] =='오선생'
df = df[c1&c2]
df

# 03. 필터링된 학생들의 수학 점수를 모두 더한 후 정수로 구하시오. 
int(df['수학'].sum())
# Out:
# 602

# %%
import pandas as pd
df = pd.read_csv("school_data.csv")
df_social = pd.read_csv("school_data_social.csv")

# 01. 두 csv파일을 '이름'을 기준으로 합치시오.
df = df.merge(df_social, on='이름')
df

# 02. 영어교사가 장선생이면서 사회교사가 오선생인 학생들을 필터링하시오. 
c1 = df['영어교사'] =='장선생' 
c2 = df['사회교사'] =='오선생'
df = df[c1&c2]
df

# 03. 필터링된 학생들의 수학 점수를 모두 더한 후 정수로 구하시오. 
int(df['수학'].sum())
# Out:
# 602

# %%
import pandas as pd
# df = pd.read_csv("school_data.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data.csv")
# df_social = pd.read_csv("school_data_social.csv")
df_social = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data_social.csv")

# '이름'을 기준으로 두 데이터프레임 합치기
merged_df = pd.merge(df, df_social, on='이름')

# 교사 필터링
cond1 = merged_df['영어교사'] == '장선생'
cond2 = merged_df['사회교사'] == '오선생'

# 필터링된 데이터에서 수학점수 합
result = merged_df[cond1 & cond2]['수학'].sum()
print(result)
# Out:
# 602

# %% [markdown]
# ### Section36.

# %% [markdown]
# - groupby().mean()은 그룹별로 '요약된 결과'만 반환하지만, 뒤에 .transform('mean')을 붙이면 원본 데이터의 모든 행 자리에 해당 그룹의 평균값을 알아서 쫙 펼쳐서 채워줍니다.

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/sales.csv")

# 01. 결측된 판매금액은 해당 지역의 평균 판매금액으로 결측값을 대체하시오. 
c = df.groupby('지역코드')['판매금액'].transform('mean')
df['판매금액'] = df['판매금액'].fillna(c)

# 02. 각 거래마다 '판매금액'과 해당 지역의 평균 판매금액의 '차이'를 절대값으로 구하시오. 
df['차이'] = (df['판매금액'] - c).abs()
df

# 03. 각 지역에서 차이값의 평균을 구한 후, 이 값이 가장 큰 지역의 지역코드를 구하시오. 
df.groupby('지역코드')['차이'].mean(numeric_only=True).idxmax()
# Out:
# 103

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/sales.csv")

# 01. 결측된 판매금액은 해당 지역의 평균 판매금액으로 결측값을 대체하시오. 
m = df.groupby('지역코드')['판매금액'].transform('mean')
m
df['판매금액'] = df['판매금액'].fillna(m)
df

# 02. 각 거래마다 '판매금액'과 해당 지역의 평균 판매금액의 '차이'를 절대값으로 구하시오. 
df['차이'] = abs(df['판매금액'] - m)
df

# 03. 각 지역에서 차이값의 평균을 구한 후, 이 값이 가장 큰 지역의 지역코드를 구하시오. 
df.groupby('지역코드')['차이'].mean().idxmax() # 103
# Out:
# 103

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/sales.csv")

# 지역별 평균 판매금액 계산 후, 결측값 대체 (transform 사용)
m = df.groupby('지역코드')['판매금액'].transform('mean')
df['판매금액'] = df['판매금액'].fillna(m)

# 각 거래별 해당 지역의 평균 판매금액 구하기
df['지역평균'] = df.groupby('지역코드')['판매금액'].transform('mean')

# 판매금액과 지역평균의 차이(절대값) 계산하여 새로운 컬럼 생성
df['차이'] = abs(df['판매금액'] - df['지역평균'])

# 지역별 차이 평균 계산 후, 최대값을 가지는 지역코드 출력
result = df.groupby('지역코드')['차이'].mean().idxmax()
print(result)
# Out:
# 103

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/store_sales.csv")

# 01. 각 행에서 판매수량과 단가를 이용하여 매출액을 계산하시오. 
df['매출액'] = df['판매수량'] * df['단가']
df
# 02. 요일을 평일과 주말로 구분하고, 매장별 평일과 주말 매출액 합계를 구하시오. 
df['평일'] = df['요일'].isin(['월','화','수','목','금']) 

c1 = df[df['평일']]
c2 = df[~df['평일']]

c1 = c1.groupby('매장코드')['매출액'].sum()
c2 = c2.groupby('매장코드')['매출액'].sum()

c1

# 03. 매장별 평일과 주말 매출액 차이을 절대값으로 구하시오. 이후, 모든 매장 중 가장 큰 절대값 차이을 찾으시오.
abs(c1 - c2).max()
# Out:
# 241975

# %% [markdown]
# ### Section38.

# %% [markdown]
# - df['총 판매액'] = df[[('Sales','A'),('Sales','B')]].sum(axis=1)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/region_sales.csv")

# 01. 각 Region과 Channel조합별로 제품(Product) A,B의 총 판매액을 계산하시오. 
df.groupby(['Region','Channel','Product']).sum().unstack()

# 02. 제품A의 매출 비율(A비율)을 구하시오. 


# 03. A비율 중 최댓값을 찾아 반올림하여 소수 줄째
# Out:
#                                           Date                       Sales  \
# Product                                      A                     B     A
# Region Channel
# East   Offline                      2025-03-15            2023-07-12   100
#        Online                       2025-07-13            2025-05-15   205
# North  Offline                      2025-04-10            2023-04-12   140
#        Online   2025-01-052023-02-122025-06-10  2025-02-102023-06-15   440
# South  Offline                      2025-01-07            2025-07-10   150
#        Online                       2025-05-20            2025-03-20   160
# West   Offline                      2025-07-01            2025-07-14   110
#        Online                       2025-07-15            2025-07-05   135
#
#
# Product           B
# Region Channel
# East   Offline  105
#        Online   210
# North  Offline  180
#        Online   420
# South  Offline  145
#        Online   170
# West   Offline  115
#        Online   130

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/region_sales.csv")

# 01. 각 Region과 Channel조합별로 제품(Product) A,B의 총 판매액을 계산하시오. 
df = df.groupby(['Region','Channel','Product']).sum().unstack()
df
# 02. 제품A의 매출 비율(A비율)을 구하시오. 
df = df[['Sales']]
df['총 판매액'] = df[[('Sales','A'),('Sales','B')]].sum(axis=1)
df
df['A비율'] = df[('Sales','A')] / df['총 판매액']
df

# 03. A비율 중 최댓값을 찾아 반올림하여 소수 줄째
round(df['A비율'].max(),2)
# Out:
# 0.51

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/region_sales.csv")

# 피벗 테이블 생성: Region, Channel별로 Product별 Sales 합계 계산
pivot_table = pd.pivot_table(df, index=['Region', 'Channel'], columns='Product',
                             values='Sales', aggfunc='sum')

# A비율 계산: 제품 A의 판매액 ÷ 총매출
pivot_table['총매출'] = pivot_table['A'] + pivot_table['B']
pivot_table['A비율'] = pivot_table['A'] / pivot_table['총매출']

# 최대 A비율 값 출력
result = pivot_table['A비율'].max()
round(result, 2)
# Out:
# 0.51

# %% [markdown]
# ### Section39.

# %% [markdown]
#  - df = df.melt(id_vars=['Region'], value_vars=['Jan','Feb','Mar'])

# %%
# 깍두기
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/monthly_sales.csv')

# 01. 지역(Region)과 월(Jan, Feb, Mar)별 매출(Sales) 합계를 구하시오. 
# df.stack()
# help(df.melt)
df = df.melt(id_vars=['Region'], value_vars=['Jan','Feb','Mar'])
df = df.groupby(['Region','variable']).sum()

# 02. 위에서 구한 결과 중, 매출 합계(Sales)가 1400을 초과하는 경우가 몇 건인지 구하시오. 
len(df[df['value'] > 1400])
# Out:
# 6

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/monthly_sales.csv')

# melt로 Wide(가로) → Long(세로) 변환
melted_df = pd.melt(
    df,
    id_vars='Region',
    value_vars=['Jan','Feb','Mar'],
    var_name='Month',
    value_name='Sales'
)

# Region, Month별 매출 합계 구하기
grouped_sales = melted_df.groupby(['Region', 'Month'])['Sales'].sum().reset_index()

# 매출 합계가 1400을 초과하는 건수
cond = grouped_sales['Sales'] > 1400
len(grouped_sales[cond])
# Out:
# 6
