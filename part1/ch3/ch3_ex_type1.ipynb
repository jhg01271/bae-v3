# %% [markdown]
# [구글 코랩(Colab)에서 실행하기](https://colab.research.google.com/github/lovedlim/bae-v3/blob/main/part1/ch3/ch3_ex_type1.ipynb)

# %% [markdown]
# - [안내] FutureWarning은 무시해도 됨

# %%
# 흔히 발생하는 FutureWarning
# df['views'].fillna(min, inplace=True)  # 변경 전 (경고 발생 가능)
# df['views'] = df['views'].fillna(min)  # 변경 후 (권장 방식)

# %% [markdown]
# ### Section1.

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")
df

# 01. 'f5'컬럼이 0이 아닌 데이터(행)을 구하시오.
c = df['f5']!=0
df1 = df[c].copy()
df1 # 120->102행


# 02. 앞에서 구한 데이터에 'views'컬럼 결측치를 'views'컬럼의 최솟값으로 채워주세요.
# print(df1['views'].median())
min_views = df1['views'].min()
# print(min_views)
df1['views'] = df1['views'].fillna(min_views)
# print(df1['views'].median()) # 5997.0 -> 5924.0
# print(help(df1.fillna))

# 03. 그리고 'views'컬럼의 중앙값을 계산해 정수로 구하시오.
int(df1['views'].median()) # 5924
# Out:
# 5924

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 0 제외
cond = df['f5'] != 0
df = df[cond]

# 'views' 컬럼 결측치 최소값으로 채우기
min = df['views'].min()
df['views'] = df['views'].fillna(min)

# 'views' 컬럼 중앙값 계산
print(int(df['views'].median()))
# Out:
# 5924

# %% [markdown]
# ### Section2.

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")
# 01. 'subscribed'컬럼에서 가장 빈도수가 많은 날짜를 구하시오.
df['subscribed'].value_counts() # 2025-02-17
# dir(df['subscribed'])

# 02. 앞에서 구한 날짜의 일(day)값을 정수로 구하시오. 
print(int(df['subscribed'].value_counts().index[0][-2:]))
# Out:
# 17

# %%
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# subscribed 종류 중 가장 많은 날짜 구하기
df = df['subscribed'].value_counts()

# 일(day)값을 찾고, 정수형으로 변경
int(df.index[0][-2:])
# Out:
# 17

# %% [markdown]
# ### Section3.

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 결측치가 있는 데이터(행)를 제거하시오.
df1 = df.dropna().copy() # 120->70행
df1

# 02. 'views'컬럼을 'f1'컬럼으로 나눈 값을 새로운 컬럼으로 추가하시오.
df1['new'] = df1['views']/df1['f1']
df1

# 03. 새로운 컬럼 값 중 가장 큰 값을 가진 행의 age를 정수로 구하시오.
c = df1['new'].max() # 423.7826086956522
int(df1[df1['new']==c]['age'].iloc[0])
# Out:
# 22

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치 제거
df = df.dropna()

# 새로운 컬럼 계산
df['new'] = df['views']/df['f1']

# 내림차순 정렬
df = df.sort_values('new', ascending=False)

# age 값 찾아서 출력
int(df.iloc[0,1])
# Out:
# 22

# %% [markdown]
# ### Section4.

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'views'컬럼의 결측 데이터를 0으로 대체하시오
# print(df.isnull().sum())
df['views'] = df['views'].fillna(0)
# print(df.isnull().sum())

# 02. 'views'컬럼에서 상위 10번째 값을 구하시오.
df = df.sort_values('views', ascending=False)
m = df.iloc[9]['views'] # 9877.0
# print(help(df.sort_values))

# 03. 'views'컬럼에서 상위 10개의 값을 상위 10번째 값으로 대체하시오.
df.iloc[:10,-1] = m

# 04. 'views'컬럼의 전체 합을 정수로 구하시오
int(df['views'].sum())


###  위험도가 높은 답안(df훼손)
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'views'컬럼의 결측 데이터를 0으로 대체하시오
# print(df.isnull().sum())
df = df.fillna(0)
# print(df.isnull().sum())

# 02. 'views'컬럼에서 상위 10번째 값을 구하시오.
df = df['views'].sort_values(ascending=False)
df.iloc[9] # 9877.0
# print(help(df['views'].sort_values))

# 03. 'views'컬럼에서 상위 10개의 값을 상위 10번째 값으로 대체하시오.
df.iloc[:9] = df.iloc[9]

# 04. 'views'컬럼의 전체 합을 정수로 구하시오
int(df.sum())
# Out:
# 652812

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측 데이터 0으로 대체
df['views'] = df['views'].fillna(0)

# 내림차순 정렬
df = df.sort_values('views',ascending=False)

# views 상위 10개 데이터에 최소값 대입
views_min = df.iloc[:10]['views'].min()
df.iloc[:10, -1] = views_min

# views 컬럼의 합
print(int(df['views'].sum()))
# Out:
# 652812

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측 데이터 0으로 대체
df['views'] = df['views'].fillna(0)

# views 컬럼에서 10번째로 큰 값을 구합니다.
value = df['views'].nlargest(10).iloc[-1]

# views 컬럼에서 가장 큰 10개의 값을 10번째로 큰 값으로 대체
df.loc[df['views'] > value, 'views'] = value

# views 컬럼의 합
print(int(df['views'].sum()))
# Out:
# 652812

# %% [markdown]
# ### Section5.

# %% [markdown]
# ##### 포함 함수 .str.contains('') 기억하기

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'f4'컬럼 데이터에 'FJ'가 포함된 데이터를 찾으시오.
# dir(df['f4'])
# help(df['f4'].isin)
# df[df['f4'].str.]
c = df['f4'].str.contains('FJ')
df = df[c]

# 02. 찾은 데이터 중에서 'f2'컬럼의 평균값을 구하시오.(반올림 후 소수 둘째자리까지 계산)
round(df['f2'].mean(),2)
# Out:
# 0.61

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# f4 컬럼에서 뒤에 2개 값 슬라이싱
df['new'] = df['f4'].str[2:4]

# FJ인 데이터 찾기
cond = df['new'] == 'FJ'
df = df[cond]

# f2 평균 구하기
print(round(df['f2'].mean(), 2))
# Out:
# 0.61

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# FJ인 데이터 찾기
cond = df['f4'].str.contains('FJ')
df = df[cond]

# f2 평균 구하기
print(round(df['f2'].mean(), 2))
# Out:
# 0.61

# %% [markdown]
# ### Section6.

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'f3'컬럼이 gold이면서 'f2' 컬럼이 2인 데이터를 찾으시오.
c = (df['f3'] == 'gold') & (df['f2']==2)
df = df[c]

# 02. 찾은 데이터에서 'f1'컬럼의 분산을 구하시오(반올림 후 소수 둘째자리까지 계산)
round(df['f1'].var(),2)
# Out:
# 235.43

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 조건에 맞는 데이터
cond1 = df['f3'] == 'gold'
cond2 = df['f2'] == 2
df = df[cond1 & cond2]

# 분산
result = df['f1'].var()

# 출력
print(round(result,2))
# Out:
# 235.43

# %% [markdown]
# ### Section7.

# %% [markdown]
# #### 절대값 함수 abs()기억하기

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 모든 나이(age)에 1을 더하시오.
df['age'] = df['age'] + 1

# 02. 20대의 'views' 평균과 30대의 'views'평균의 차이의 절대값을 구하시오. (반올림 후 소수 둘째자리까지 계산)
c_20 = df['age'] // 10 == 2
c_30 = df['age'] // 10 == 3
round(abs(df[c_20]['views'].mean() - df[c_30]['views'].mean()),2) # 263.13
# Out:
# 263.13

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 나이 + 1
df['age'] = df['age'] + 1

# 20대, 30대 조건
cond1 = (df['age'] >= 20) & (df['age'] < 30)
cond2 = (df['age'] >= 30) & (df['age'] < 40)

# 30대 views
result = abs(df[cond1]['views'].mean() - df[cond2]['views'].mean())

print(round(result,2))
# Out:
# 263.13

# %% [markdown]
# ### Section8.

# %% [markdown]
# ##### pd.to_datetime(df['subscribed'])
# - df['y'] = df['subscribed'].dt.year
# - df['m'] = df['subscribed'].dt.month

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'subscribed'컬럼이 2024년 2월인 데이터를 찾으시오.
c = df['subscribed'].str.contains('2024-02')
df = df[c]

# 02. 위에서 찾은 데이터 중 'f3'컬럼이 gold인 데이터의 개수를 구하시오.
c1 = df['f3'] == 'gold'
len(df[c1]) # 5
# Out:
# 5

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'subscribed'컬럼이 2024년 2월인 데이터를 찾으시오.
c = df['subscribed'] = pd.to_datetime(df['subscribed'])
df['y'] = df['subscribed'].dt.year
df['m'] = df['subscribed'].dt.month
df

c1 = df['y'] == 2024
c2 = df['m'] == 2
df = df[c1&c2]

# 02. 위에서 찾은 데이터 중 'f3'컬럼이 gold인 데이터의 개수를 구하시오.
len(df[df['f3'] == 'gold'])
# Out:
# 5

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 자료형 변환
df['subscribed'] = pd.to_datetime(df['subscribed'])
# df['subscribed'] = pd.to_datetime(df['subscribed'], format="%Y-%m-%d") # format 사용

# 파생변수 생성 (년, 월)
df['year'] = df['subscribed'].dt.year
df['month'] = df['subscribed'].dt.month

# 2024년 2월이고, 'f3'이 gold인 데이터
cond1 = df['year'] == 2024
cond2 = df['month'] == 2
cond3 = df['f3'] == 'gold'
df = df[cond1 & cond2 & cond3]

# 데이터 개수
print(len(df))
# Out:
# 5

# %% [markdown]
# ### Section9.

# %% [markdown]
# ##### .value_counts().index[0] 또는 .mode()[0]으로 최빈값 구하기

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'views'컬럼 값이 1000 이하인 데이터(결측치 제외)를 찾으시오.
df = df[df['views'] <= 1000]

# 02. 앞에서 구한 데이터 중 'f4' 컬럼의 최빈값을 구하시오.
# df['f4'].value_counts().index[0] # ISFJ
df['f4'].mode()[0]
# Out:
# 'ISFJ'

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# views수가 1000이하
cond = df['views'] <= 1000
df = df[cond]

# f4컬럼 종류별 개수
df = df['f4'].value_counts()

# f4컬럼 최빈값
print(df.index[0])
# Out:
# ISFJ

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# views수가 1000이하
cond = df['views'] <= 1000
df = df[cond]

# f4컬럼 종류별 개수
print(df['f4'].mode()[0])
# Out:
# ISFJ

# %% [markdown]
# ### Section10.

# %% [markdown]
# ##### df.groupby('city').mean(numeric_only=True) 사용법 유의

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 결측치에 있는 행을 삭제하시오.
df = df.dropna()
# df.info()

# 02. 결측치가 삭제된 데이터를 사용하여 지역별(city)평균을 계산하시오.
# help(df.groupby('city'))
df = df.groupby('city').mean(numeric_only=True)

# 03. 앞에서 계산한 지역별 평균 데이터에서 'f2'컬럼 값이 가장 큰 지역을 구하시오. # 서울
df['f2'].idxmax()
# Out:
# '서울'

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 있는 행은 삭제하고
df.dropna(inplace=True)

# 지역별 평균 계산
df = df.groupby(['city']).mean(numeric_only=True) # 시험환경은 mean() 사용

# 'f2'컬럼이 가장 큰 지역 출력
print(df.sort_values("f2", ascending = False).index[0])
# Out:
# 서울

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 있는 행은 삭제하고
df.dropna(inplace=True)

# 지역별 평균 계산
df = df.groupby('city').mean(numeric_only=True) # 시험환경은 mean() 사용

# 'f2'컬럼이 가장 큰 지역 출력
print(df['f2'].idxmax())
# Out:
# 서울

# %% [markdown]
# ### Section11.

# %% [markdown]
# ##### 버림 .floor(), 올림 .ceil()
# - int(len(df) * 0.7) 앞에서부터 70% 자르기
# - df = df.iloc[:end]

# %%
# 깍두기
import pandas as pd
# import math
df = pd.read_csv("type1_data1.csv")

# 01. 데이터에서 결측치가 있는 데이터(행)을 모두 제거하시오.
# df.info()
df = df.dropna()
# df.info()

# 02. 결측치가 제거된 데이터를 사용하여 앞에서부터 70% 데이터를 구하시오.(단, 데이터 70% 지점의 index가 소수점으로 계산될 경우 소수점 이하는 버림) -> int()하면 버려짐
# dir(df)
c = int(len(df)*0.7)
df = df.iloc[:c]
# df.reset_index()

# 03. 앞에서 구한 70% 데이터 중 'views'컬럼의 3사분위수에서 1사분위수를 뺀 값을 정수로 구하시오.
# help(df.quantile)
int(df['views'].quantile(.75) - df['views'].quantile(.25))
# Out:
# 2771

# %%
import pandas as pd
import math
df = pd.read_csv("type1_data1.csv")

# 01. 데이터에서 결측치가 있는 데이터(행)을 모두 제거하시오.
# df.info()
df = df.dropna()
# df.info()

# 02. 결측치가 제거된 데이터를 사용하여 앞에서부터 70% 데이터를 구하시오.(단, 데이터 70% 지점의 index가 소수점으로 계산될 경우 소수점 이하는 버림)
# dir(df)
df = df.reset_index()
math.floor(70*0.7) # 49
df = df[:49]

# 03. 앞에서 구한 70% 데이터 중 'views'컬럼의 3사분위수에서 1사분위수를 뺀 값을 정수로 구하시오.
# help(df.quantile)
int(df['views'].quantile(.75) - df['views'].quantile(.25))
# Out:
# 2771

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 있는 행 제거
df.dropna(inplace=True)

# 70% 지점
end = int(len(df) * 0.7)

# 70% 데이터 슬라이싱
df = df.iloc[:end]

# 3사분위수, 1사분위수
q3 = df['views'].quantile(.75)
q1 = df['views'].quantile(.25)

# 결과 출력
print(int(q3 - q1))
# Out:
# 2771

# %% [markdown]
# ### Section12.

# %% [markdown]
# - df.isnull().sum()
# - df = df.dropna(subset=['f1'])

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 결측치가 가장 많은 두 컬럼을 찾으시오.
# df.info() # f1, f3
# df.isnull().sum()

# 02. 첫 번째로 결측치가 많은 컬럼에서 결측치가 있는 데이터(행)를 삭제하시오.
df = df.dropna(subset=['f1'])
# help(df.dropna)
df

# 03. 두번째로 결측치가 많은 컬럼을 최빈값으로 대체하시오.
c = df['f3'].value_counts().idxmax() # gold
df['f3'] = df['f3'].fillna(c)

# 04. 'f3'컬럼의 'gold' 값을 가진 데이터의 수를 정수형으로 구하시오.
df['f3'].value_counts() # 63
# Out:
# f3
# gold      63
# silver    15
# vip       11
# Name: count, dtype: int64

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 가장 많은 컬럼, 출력 결과로 확인
#print(df.isnull().sum())

# 결측치가 가장 많은 컬럼 제거
df = df.dropna(subset=['f1'])

# 두번째로 가장 결측치가 많은 컬럼 최빈값 대체
freq = df['f3'].mode()[0]
df['f3'] = df['f3'].fillna(freq)

# f3컬럼이 gold인 데이터의 수
print(sum(df['f3'] == 'gold'))
# Out:
# 63

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 가장 많은 컬럼
col = df.isnull().sum().idxmax()

# 결측치가 가장 많은 컬럼 제거
df = df.dropna(subset=[col])

# 두번째로 가장 결측치가 많은 컬럼 최빈값 대체
freq = df['f3'].mode()[0]
df['f3'] = df['f3'].fillna(freq)

# f3컬럼이 gold인 데이터의 수
print(len(df[df['f3'] == 'gold']))
# Out:
# 63

# %% [markdown]
# ### Section13.

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'f1' 컬럼에 결측치가 있는 데이터만 선택하시오.
c = df['f1'].isnull()
df = df[c]

# 02. 선택된 데이터에서 'age'컬럼의 평균값을 구하시오.(반올림 후 소수 첫째짜리까지 계산)
round(df['age'].mean(),1)
# Out:
# 53.6

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치가 있는 데이터 True / False
cond = df['f1'].isnull()

# 결측치가 있는 데이터 선택
df = df[cond]

# age의 평균값을 구하시오
result = df['age'].mean()

# 소수 첫째자리 까지 출력
print(round(result, 1))
# Out:
# 53.6

# %% [markdown]
# ### Section14.

# %% [markdown]
# - mapping = {'silver':1,'gold':2,'vip':3}
# - df['f3'] = df['f3'].replace(mapping)
# - map보다 replace추천: map쓰려면 0에 대해서도 규칙 써줘야함 0:0

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 중복 데이터를 제거하시오.
df = df.drop_duplicates()
df

# 02. 'f3' 컬럼의 결측치는 0, 'silver'는 1, 'gold'는 2, 'vip'는 3으로 변환하시오. (map보다 replace추천: map쓰려면 0에 대해서도 규칙 써줘야함 0:0)
df['f3'] = df['f3'].fillna(0)
mapping = {'silver':1,'gold':2,'vip':3}
# help(df['f3'].map)
df['f3'] = df['f3'].replace(mapping)
df['f3'].value_counts()

# 03. 변환된 'f3'컬럼의 총합을 정수형으로 구하시오. 
int(df['f3'].sum())
# Out:
# C:\Users\iljoo\AppData\Local\Temp\ipykernel_41728\1587783712.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['f3'] = df['f3'].replace(mapping)
# 167

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 중복 데이터를 제거하시오.
df = df.drop_duplicates()
df

# 02. 'f3' 컬럼의 결측치는 0, 'silver'는 1, 'gold'는 2, 'vip'는 3으로 변환하시오. (데이터 오염 높아 비추천)
df['f3'] = df['f3'].fillna(0)
c1 = df['f3'] == 'silver'
c2 = df['f3'] == 'gold'
c3 = df['f3'] == 'vip'
df[c1] = 1
df[c2] = 2
df[c3] = 3
df['f3'].value_counts()

# 03. 변환된 'f3'컬럼의 총합을 정수형으로 구하시오. 
int(df['f3'].sum())
# Out:
# 167

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 중복데이터 제거
df = df.drop_duplicates()

# 값 대체
import numpy as np
dict_list = {np.nan:0, 'silver':1, 'gold':2, 'vip':3}
df['f3'] = df['f3'].map(dict_list)

# f3컬럼의 총합 (정수형으로 출력)
print(int(df['f3'].sum()))
# Out:
# 167

# %%
# 방법2
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 중복데이터 제거
df.drop_duplicates(inplace=True)

# 계산
r1 = sum(df['f3'] == 'silver') * 1
r2 = sum(df['f3'] == 'gold') * 2
r3 = sum(df['f3'] == 'vip') * 3
print(r1 + r2 + r3)
# Out:
# 167

# %% [markdown]
# ### Section15.

# %% [markdown]
# - df.sum(axis=1)을 써주면 좌에서 우로(가로 방향) 각 행의 합을 구해줌

# %%
# 깍두기
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 주어진 데이터에서 문자 자료형 컬럼을 삭제하시오.
# help(df.drop)
# dir(df)
# help(df.select_dtypes)
df = df.select_dtypes(exclude=['object'])
# print(df.info())
# 02. 숫자 자료형 컬럼의 결측치를 0으로 대체하시오.
df = df.fillna(0)
# df.info()

# 03. 각 행의 합이 3000보다 큰 값의 개수를 정수로 구하시오. (각 행의 합: 'age'+'f1'+'f2'+'f5'+'views')
df['sum'] = df.sum(axis=1)
int(len(df[df['sum'] > 3000]))
# Out:
# 88

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 자료형이 object 컬럼 선택
cols = df.select_dtypes(exclude='object').columns
df = df[cols]

# 결측치 0으로 대체
df = df.fillna(0)

# 행과 열 변경
df = df.T

# 행별 합이 3000이상인 데이터 수
print(sum(df.sum() > 3000))
# Out:
# 88

# %% [markdown]
# ### Section16.

# %% [markdown]
# - q1 = df['views'].quantile(.25)
# -  q3 = df['views'].quantile(.75)
# -  iqr = q3 - q1
# -
# - df = df[c3 | c4]

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'views'컬럼의 1사분위수, 3사분위수 그리고 IQR을 계산하시오.
dir(df)
q1 = df['views'].quantile(.25)
q3 = df['views'].quantile(.75)
iqr = q3 - q1
iqr

# 02. 이상치 조건에 맞는 데이터를 찾으시오.(이상치는 1사분위수 - (IQR * 1.5)보다 작은 값과 3사분위수 + (IQR * 1.5) 보다 큰 값)
c3 = df['views'] < q1 - iqr * 1.5 
c4 = df['views'] > q3 + iqr * 1.5
df = df[c3 | c4]

# 03. 이상치 데이터의 'views'컬럼 합을 정수로 구하시오.
int(df['views'].sum())
# Out:
# 77699

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 3사분위 1사분위
q3 = df['views'].quantile(.75)
q1 = df['views'].quantile(.25)

# IQR 계산
IQR = q3 - q1

# 이상치 기준 찾기
line1 = q1 - 1.5 * IQR
line2 = q3 + 1.5 * IQR

# 이상치 조건에 만족하는 데이터 찾기
cond1 = df['views'] < line1
cond2 = df['views'] > line2
df = df[cond1 | cond2]

# views 컬럼 합
print(int(df['views'].sum()))
# Out:
# 77699

# %% [markdown]
# ### Section17.

# %% [markdown]
# - 소수점이 존재하는 값 제거: df = df[df['age'] == df['age'].astype(int)]
# - cond = df['age'] == round(df['age'],0)

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 'views'컬럼의 표준편차를 구하시오.
c1 = df['views'].std()

# 02. 'age'컬럼의 이상치(소수점 나이, 음수 나이, 0살)를 제거하고, 'views'컬럼의 표준편차를 구하시오.
df = df[df['age'] > 0]
df['age'].value_counts()
# help(df['age'].astype)
df = df[df['age'] == df['age'].astype(int)]

# 03. 이상치 제거 전후의 'views'컬럼의 표준편차를 더하여, 반올림 후 소수 둘째자리까지 구하시오. 
c2 = df['views'].std()
round(c1+c2,2)
# Out:
# 8297.31

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 표준편차
r1 = df['views'].std()

# 음수이거나 0 테이터 제외
cond = df['age'] <= 0
df = df[~cond]

# 소수점이 없는 값만 선택
cond = df['age'] == round(df['age'],0)
df = df[cond]

# 표준편차
r2 = df['views'].std()

print(round(r1 + r2, 2))
# Out:
# 8297.31

# %% [markdown]
# ### Section18.

# %% [markdown]
# ##### 02. index '2003'데이터(행)에서 평균보다 작은 값의 개수를 구하시오.
# - mean_2003 = df.loc[2003].mean() # 97.215
# - len(df.loc[2003][df.loc[2003] < mean_2003])

# %%
import pandas as pd
df = pd.read_csv("type1_data2.csv", index_col="year")

# 01. index '2001'데이터(행)에서 평균보다 큰 값의 개수를 구하시오.
df1 = df.copy()
df1['mean'] = df1.mean(axis=1) # 	104.235
mean_2001 = df1.iloc[1,-1]
c1 = len(df.T[df.T[2001] > mean_2001])

# 02. index '2003'데이터(행)에서 평균보다 작은 값의 개수를 구하시오.
mean_2003 = df.loc[2003].mean() # 97.215
len(df.loc[2003][df.loc[2003] < mean_2003])

# 03. 두 개수를 더하시오.
c1 + c2
# Out:
# 202

# %%
import pandas as pd
# df = pd.read_csv("type1_data2.csv", index_col="year")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data2.csv", index_col="year")

# 2001, 평균보다 큰값 합계
m1 = df.loc[2001].mean()
cond1 = df.loc[2001] > m1
r1 = sum(cond1)

# 2003평균보다 작은값 합계
m2 = df.loc[2003].mean()
cond2 = df.loc[2003] < m2
r2 = sum(cond2)

print(r1+r2)
# Out:
# 202

# %%
import pandas as pd
# df = pd.read_csv("type1_data2.csv", index_col="year")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data2.csv", index_col="year")
df = df.T # 행과 열 변경

# 평균보다 큰값 합계
m1 = df[2001].mean()
cond1 = df[2001] > m1
r1 = sum(cond1)

# 평균보다 작은값 합계
m2 = df[2003].mean()
cond2 = df[2003] < m2
r2 = sum(cond2)

print(r1+r2)
# Out:
# 202

# %% [markdown]
# ### Section19.

# %% [markdown]
# - df.bfill(): 결측치 바로 뒤에 있는값으로 대체
# - df = df.groupby(['city','f2']).sum(numeric_only=True) # .reset_index()를 붙이면 연산 처리하기 좋음

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 결측치를 바로 뒤에 있는 값으로 대체하시오.(바로 뒤의 값도 결측치일 경우, 뒤에 있는 데이터 중 가장 가까운 값으로 대체)
df = df.bfill()
# dir(df)
df

# 02. 'city'와 'f2'컬럼을 기준으로 그룹합을 계산하시오.
df = df.groupby(['city','f2']).sum(numeric_only=True) # .reset_index()를 붙이면 연산 처리하기 좋음

# 03. 'views'값이 세 번째로 큰 city이름을 구하시오.
# dir(df['views'])
df['views'].nlargest(3) # 경기
# Out:
# city  f2
# 경기    0     154066.0
# 대구    0     100421.0
# 경기    1      91442.0
# Name: views, dtype: float64

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 결측치 채우기
df = df.bfill()

# city와 f2기준 그룹합 계산
df = df.groupby(['city','f2']).sum(numeric_only=True).reset_index()

# 내림차순 정렬
df = df.sort_values('views', ascending=False)

# 3번째로 큰 값 출력
print(df.iloc[2,0])
# Out:
# 경기

# %% [markdown]
# ### Section20.

# %% [markdown]
# - to_datetime앞에 pd이다. pd.to_datetime(df['subscribed'])

# %%
import pandas as pd
df = pd.read_csv("type1_data1.csv")

# 01. 연도 구분 없이 월별로 숫자형 컬럼의 합을 구하시오.
df['subscribed'] = pd.to_datetime(df['subscribed'])

# dir(df['subscribed'])
df['month'] = df['subscribed'].dt.month
df = df.groupby('month').sum(numeric_only=True)
df

# 02. 합계 중 'views'가 가장 작은 값을 가진 월을 정수로 구하시오. 
int(df['views'].idxmin())
# Out:
# 11

# %%
import pandas as pd
# df = pd.read_csv("type1_data1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/type1_data1.csv")

# 자료형 변환
df['subscribed'] = pd.to_datetime(df['subscribed'])

# 파생변수 생성
df['month'] = df['subscribed'].dt.month

# 월별로 데이터 합 집계
df = df.groupby('month').sum(numeric_only=True)

# 오름차순 정렬 및 가장 작은값 출력
print(df.sort_values('views').index[0])
# Out:
# 11

# %% [markdown]
# ### Section21.

# %% [markdown]
# - 날짜 계산 전 pd.to_datetime 필수!
# - .dt.total_seconds()/60하면 분단위로 계산 가능

# %%
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 예상 도착 시간보다 늦게 도착한 건수를 구하시오.
df['예상도착시간'] = pd.to_datetime(df['예상도착시간'])
df['실제도착시간'] = pd.to_datetime(df['실제도착시간'])
df = df[df['예상도착시간'] < df['실제도착시간']] # 데이터가 이쁘게 안들어가 있다면 위험함
len(df)

# 02. 이 중 거리가 7km 이상인 데이터의 수를 정수로 구하시오. 
len(df[df['거리'] >= 7])
# Out:
# 311

# %%
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 예상 도착 시간보다 늦게 도착한 건수를 구하시오.
df = df[df['예상도착시간'] < df['실제도착시간']] # 데이터가 이쁘게 안들어가 있다면 위험함
len(df)

# 02. 이 중 거리가 7km 이상인 데이터의 수를 정수로 구하시오. 
len(df[df['거리'] >= 7])
# Out:
# 311

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# datetime으로 자료형 변경
df['실제도착시간'] = pd.to_datetime(df['실제도착시간'])
df['예상도착시간'] = pd.to_datetime(df['예상도착시간'])

# 지연시간 계산(분)
df['지연시간'] = (df['실제도착시간'] - df['예상도착시간']).dt.total_seconds()/60

# 조건1 - 예상 도착시간보다 늦게 도착한 건
cond1 = df['지연시간'] > 0

# 조건2 - 거리가 7 이상인 건
cond2 = df['거리'] >= 7

# 조건에 맞는 데이터(행) 수 출력
print(len(df[cond1 & cond2]))
# Out:
# 311

# %% [markdown]
# ### Section22.

# %%
import pandas as pd
df = pd.read_csv("delivery_time.csv")

# 01. 주문 시간과 실제 도착 시간의 차이를 분 단위로 계산하시오.

# 02. 앱 종류별로 평균 도착 시간(분)을 계산하시오.

# 03. 평균적으로 가장 빠른 앱 종류를 찾고, 해당 앱의 평균 도착 시간을 분으로 반올림하여 정수로 구하시오.

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# datetime으로 자료형 변경
df['실제도착시간'] = pd.to_datetime(df['실제도착시간'])
df['주문시간'] = pd.to_datetime(df['주문시간'])

# 실제 도착시간과 주문시간 차이 계산(분)
df['diff'] = (df['실제도착시간'] - df['주문시간']).dt.total_seconds()/60

# 앱종류별 도착시간과 주문시간 차이의 평균 계산
df = df.groupby('앱종류')['diff'].mean()

# 가장 작은 시간(분) 반올림 후 출력
print(round(df.min()))
# Out:
# 62

# %% [markdown]
# ### Section23.

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# datetime 자료형으로 변경
df['실제도착시간'] = pd.to_datetime(df['실제도착시간'])
df['예상도착시간'] = pd.to_datetime(df['예상도착시간'])

# 지연시간 계산(분)
df['지연시간'] = (df['실제도착시간'] - df['예상도착시간']).dt.total_seconds() / 60  # 분 단위로 계산

# 실제 도착시간이 예상 도착시간보다 늦은 경우를 체크하는 컬럼 생성
df['지연여부'] = df['지연시간'] > 0

# 결제 종류별 지연된 주문의 비율 계산
result = df.groupby('결제종류')['지연여부'].mean()

# 가장 비율이 높은 값
print(round(result.max(), 2))
# Out:
# 0.56

# %% [markdown]
# ### Section24.

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")
df.head()

# 사용자별로 주문 거리의 합계와 평균 계산
df_distance = df.groupby('user')['거리'].sum()

# 주문 거리의 합계가 50km 이상인 사용자만 필터링
cond = df_distance >= 50
df_distance = df_distance[cond]

# 주문 거리의 합계가 50km 이상인 사용자들의 데이터 필터링
filtered_data = df[df['user'].isin(df_distance.index)]
filtered_data

# 해당 사용자들의 선호 결제 방식 중 큰 값
payment_method = filtered_data['결제종류'].value_counts()
print(payment_method.iloc[0])
# Out:
# 48

# %% [markdown]
# ### Section25.

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# 각 사용자별로 첫 주문과 마지막 주문 사이의 시간 간격(일 단위)을 계산
df['주문시간'] = pd.to_datetime(df['주문시간'])
min_order_time = df.groupby('user')['주문시간'].min()
max_order_time = df.groupby('user')['주문시간'].max()
time_interval = (max_order_time - min_order_time).dt.days

# 1회 이하 주문 제외
cond1 = time_interval>0
m = time_interval[cond1].mean()

# 평균보다 기간이 긴 유저 수
cond2 = time_interval > m
print(len(time_interval[cond2]))
# Out:
# 146

# %% [markdown]
# ### Section26.

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# 주문이 가장 많이 발생한 연-월 찾기
df['주문시간'] = pd.to_datetime(df['주문시간'])
df['주문월'] = df['주문시간'].dt.to_period('M')
year_month = df['주문월'].value_counts().idxmax()

# 해당 연-월에 배고팡 앱을 통한 주문 중, '앱결제'로 결제된 주문의 비율 계산
cond1 = df['주문월'] == year_month
cond2 = df['앱종류'] == '배고팡'
filtered_df = df[cond1 & cond2]
cond3 = filtered_df['결제종류'] == '앱결제'
result = len(filtered_df[cond3])/len(filtered_df)
print(round(result,2))
# Out:
# 0.31

# %% [markdown]
# ### Section27.

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# datetime 자료형으로 변경
df['주문시간'] = pd.to_datetime(df['주문시간'])
df['실제도착시간'] = pd.to_datetime(df['실제도착시간'])

# 점심시간 주문 선택
df['시간'] = df['주문시간'].dt.hour
cond1 = df['시간'] >= 10
cond2 = df['시간'] < 13
df = df[cond1 & cond2]

# 속도(km/h) = 거리(km) / 시간(h)
df['배달시간'] = df['실제도착시간'] - df['주문시간']
df['배달시간'] = df['배달시간'].dt.total_seconds() / 60 / 60 # 시간 단위로 변경
df['속도'] = df['거리'] / df['배달시간']
sum(df['속도'] >= 50)
# Out:
# 1

# %% [markdown]
# ### Section28.

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# 주문 연월 추출 (연도-월)
df['주문시간'] = pd.to_datetime(df['주문시간'])
df['주문월'] = df['주문시간'].dt.to_period('M')

# 주문월을 기준으로 빈도 수(주문 횟수) 계산
count_month = df.groupby('주문월').size()

# 주문 횟수가 가장 많은 월의 인덱스 추출
year_month = count_month.idxmax()

# 문자열로 변경 및 하이픈(-) 제거
year_month = str(year_month)
result = year_month.replace("-","")
print(result)
# Out:
# 202209

# %% [markdown]
# ### Section29.

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# 배달료 계산 함수 정의
def delivery_fee(distance):
    if distance < 5:
        return 2000
    elif distance < 10:
        return 4000
    elif distance < 15:
        return 6000
    elif distance < 20:
        return 8000

# 각 주문에 대한 배달료 계산
df['배달료'] = df['거리'].apply(delivery_fee)

# 월별로 배달료 집계
df['주문시간'] = pd.to_datetime(df['주문시간'])
period_M = df['주문시간'].dt.to_period("M")
monthly = df.groupby(period_M)['배달료'].sum()

# 가장 많은 배달료가 발생한 월과 그 월의 총 배달료 찾기
max_fee_month = monthly.idxmax()
max_fee_value = monthly[max_fee_month]
print(max_fee_value)
# Out:
# 448000

# %% [markdown]
# ### Section30.

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")
df['주문시간'] = pd.to_datetime(df['주문시간'])

# 주말/평일 구분 0:월, 1:화 ~ 5:토, 6:일
df['dayofweek'] = df['주문시간'].dt.dayofweek
df['주말'] = df['dayofweek'] >= 5

# 주말 개수, 평일 개수 계산
weekend = sum(df['주말'])
weekday = sum(~df['주말'])

# 차이 절대값 출력
print(abs(weekend - weekday))
# Out:
# 412

# %% [markdown]
# ### Section31.

# %%
import pandas as pd
# df = pd.read_csv("delivery_time.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/delivery_time.csv")

# 문자 슬라이싱
df['user_int'] = df['user'].str[5:]

# 자료형 변환
df['user_int'] = df['user_int'].astype(int)

# 합계
print(df['user_int'].sum())
# Out:
# 261387

# %% [markdown]
# ### Section32.

# %%
import pandas as pd
# df = pd.read_csv("school_data.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data.csv")

# 수학, 영어, 국어 점수 합계
df['total_score'] = df[['수학', '영어', '국어']].sum(axis=1)

# 합계 점수를 기준으로 상위 10명 선택
top10 = df.nlargest(10, 'total_score')

# 선택된 10명의 수학 평균 점수 계산
result = top10['수학'].mean()
print(round(result))
# Out:
# 82

# %% [markdown]
# ### Section33.

# %%
import pandas as pd
# df = pd.read_csv("school_data.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data.csv")

# 이름을 유지하면서 수학, 영어, 국어 형태 변경
melted_df = df.melt(id_vars=['이름'], value_vars=['수학', '영어', '국어'])

# 가장 작은 값 25개의 합
result = melted_df['value'].nsmallest(25).sum()
print(result)
# Out:
# 420

# %% [markdown]
# ### Section34.

# %%
import pandas as pd
# df = pd.read_csv("school_data.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data.csv")
# df_science = pd.read_csv("school_data_science.csv")
df_science = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data_science.csv")

# 두 데이터프레임 합치기(axis=1)
df = pd.concat([df, df_science], axis=1)

# 수평(열)으로 평균 계산
df['수영국과 평균'] = df[['수학', '영어', '국어', '과학']].mean(axis=1)

# 수학, 영어, 국어, 과학 평균이 60점 이상
result = sum(df['수영국과 평균'] >= 60)
print(result)
# Out:
# 9

# %% [markdown]
# ### Section35.

# %%
import pandas as pd
# df = pd.read_csv("school_data.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data.csv")
# df_social = pd.read_csv("school_data_social.csv")
df_social = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part1/ch3/school_data_social.csv")

# '이름'을 기준으로 두 데이터프레임 합치기
merged_df = pd.merge(df, df_social, on='이름')

# 교사 필터링
cond1 = merged_df['영어교사'] == '장선생'
cond2 = merged_df['사회교사'] == '오선생'

# 필터링된 데이터에서 수학점수 합
result = merged_df[cond1 & cond2]['수학'].sum()
print(result)
# Out:
# 602

# %% [markdown]
# ### Section36.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/sales.csv")

# 지역별 평균 판매금액 계산 후, 결측값 대체 (transform 사용)
m = df.groupby('지역코드')['판매금액'].transform('mean')
df['판매금액'] = df['판매금액'].fillna(m)

# 각 거래별 해당 지역의 평균 판매금액 구하기
df['지역평균'] = df.groupby('지역코드')['판매금액'].transform('mean')

# 판매금액과 지역평균의 차이(절대값) 계산하여 새로운 컬럼 생성
df['차이'] = abs(df['판매금액'] - df['지역평균'])

# 지역별 차이 평균 계산 후, 최대값을 가지는 지역코드 출력
result = df.groupby('지역코드')['차이'].mean().idxmax()
print(result)
# Out:
# 103

# %% [markdown]
# ### Section37.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/store_sales.csv")

# 매출액 계산
df['매출액'] = df['판매수량'] * df['단가']

# 요일별 평일/주말 구분 딕셔너리
day_mapping = {'월': '평일', '화': '평일', '수': '평일', '목': '평일', '금': '평일',
               '토': '주말', '일': '주말'}

# 매핑을 활용하여 새로운 열 추가
df['구분'] = df['요일'].map(day_mapping)

# 매장코드 & 평일/주말별 매출액 합계
store_sales = df.groupby(['매장코드', '구분'])['매출액'].sum().unstack()

# 평일과 주말 매출액 차이 계산
store_sales['차이'] = abs(store_sales['평일'] - store_sales['주말'])

# 전체 매장 중 매출액 편차가 가장 큰 매장의 편차 값 찾기
store_sales['차이'].max()
# Out:
# 241975

# %% [markdown]
# ### Section38.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/region_sales.csv")

# 피벗 테이블 생성: Region, Channel별로 Product별 Sales 합계 계산
pivot_table = pd.pivot_table(df, index=['Region', 'Channel'], columns='Product',
                             values='Sales', aggfunc='sum')

# A비율 계산: 제품 A의 판매액 ÷ 총매출
pivot_table['총매출'] = pivot_table['A'] + pivot_table['B']
pivot_table['A비율'] = pivot_table['A'] / pivot_table['총매출']

# 최대 A비율 값 출력
result = pivot_table['A비율'].max()
round(result, 2)
# Out:
# 0.51

# %% [markdown]
# ### Section39.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert_v2/refs/heads/main/part1/ch3/monthly_sales.csv')

# melt로 Wide(가로) → Long(세로) 변환
melted_df = pd.melt(
    df,
    id_vars='Region',
    value_vars=['Jan','Feb','Mar'],
    var_name='Month',
    value_name='Sales'
)

# Region, Month별 매출 합계 구하기
grouped_sales = melted_df.groupby(['Region', 'Month'])['Sales'].sum().reset_index()

# 매출 합계가 1400을 초과하는 건수
cond = grouped_sales['Sales'] > 1400
len(grouped_sales[cond])
# Out:
# 6
